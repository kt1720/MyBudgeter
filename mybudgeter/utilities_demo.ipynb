# %% [markdown]
# ## Test for functions in utilties

# %%
from datetime import datetime
from utilities import users
from utilities.helper import calculation_query, spending_query, linechart_query
# %reload_ext autoreload
# %autoreload 2

user = users.User(budget = 'budgeting.db', transactions = "transactions.db")
print(user.total(categories = "food"))
print(user.total())
print(user.total(months=12))
print(user.total(type="budget"))
print(user.total(type="budget", categories=["food", "entertainment"]))
print(user.total(type="budget", years=2023))
del user
# Out:
# 25
# 120
# 70
# 1600
# 300
# 1600

# %%
user = users.User(budget = 'budgeting.db', transactions = "transactions.db")
print(user.remaining_budget())
print(user.remaining_budget(categories="food", month=12))
print(user.remaining_budget(categories="food"))
del user
# Out:
# 1480
# 125
# 225

# %%
user = users.User(budget = 'budgeting.db', transactions = "transactions.db")
print(user.average(months=12))
print(user.average(type="budget", months=12))
print(user.average(type="budget", years=2023))
del user
# Out:
# 17.5
# 125.0
# 228.57142857142858

# %%
user = users.User(budget = 'budgeting.db', transactions = "transactions.db")
print(user.highest_spending())
print(user.highest_spending(False))
print(user.lowest_spending())
print(user.lowest_spending(False))
del user
# Out:
# ('school', 60)
# ('12', 70)
# ('food', 25)
# ('09', 50)

# %%
user = users.User(budget = 'budgeting.db', transactions = "transactions.db")
user.summary()
user.pie_chart()
user.pie_chart("budget")
user.line_chart()
user.line_chart("budget")
del user
# Out:
# ===== Budget Summary =====
# Remaining Budget: $1480.00
#
# Category Breakdown:
# Highest Spending Category: School
# Spending: $60.00
# Lowest Spending Category:Food
# Spending: $25.00
#
# Monthly Breakdown:
# Highest Spending Month: 12
# Spending: $70.00
# Lowest Spending Month: 09
# Spending: $50.00
#
# You are within budget. Keep it up!

# %%
import sqlite3

tr_db = sqlite3.connect("transactions.db")
bg_db = sqlite3.connect("budgeting.db")
tr_cursor = tr_db.cursor()
bg_cursor = bg_db.cursor()
tr_cursor.execute("""SELECT * FROM transactions;
                  """)
bg_cursor.execute("""SELECT * FROM budget;""")
tr_rows = tr_cursor.fetchall()
bg_rows = bg_cursor.fetchall()
for row in tr_rows:
    print(row)

for row in bg_rows:
    print(row)
# Out:
# (1, '2023-12-03', 'books', 'school', 10)
# (3, '2023-12-01', 'dinner', 'food', 15)
# (5, '2023-09-10', 'upass', 'school', 50)
# (7, '2023-12-04', 'lunch', 'food', 10)
# (9, '2023-12-04', 'fruits', 'grocery', 35)
# ('food', 12, 2023, 150)
# ('clothing', 12, 2023, 100)
# ('entertainment', 12, 2023, 50)
# ('food', 10, 2023, 100)
# ('school', 9, 2023, 200)
# ('rent', 8, 2023, 800)
# ('grocery', 12, 2023, 200)
